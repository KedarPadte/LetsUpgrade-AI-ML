# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
print('Pandas version:',pd.__version__)
print("numpy version: ", np.__version__)
print("matplotlib version: ", matplotlib.__version__)
print("seaborn version: ",sns.__version__)
# Out:
# Pandas version: 1.0.5
# numpy version:  1.18.5
# matplotlib version:  3.2.2
# seaborn version:  0.10.1

# %%
os.chdir('E:\LetsUpgrade\DATASETS')

cc=pd.read_csv('creditcard.csv')
cc
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
cc.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
cc.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
cc.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
cc['Amount'].max()
# Out:
# 25691.16

# %%
cc['Amount'].min()
# Out:
# 0.0

# %%
cc['Amount'].value_counts()
# Out:
# 1.00       13688
# 1.98        6044
# 0.89        4872
# 9.99        4747
# 15.00       3280
#            ...
# 192.63         1
# 218.84         1
# 195.52         1
# 793.50         1
# 1080.06        1
# Name: Amount, Length: 32767, dtype: int64

# %%
print(type(cc))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
os.getcwd()
# Out:
# 'E:\\LetsUpgrade\\DATASETS'

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
cc.iloc[[99,102,990]]
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 99    68.0  1.232996  0.189454  0.491040  0.633673 -0.511574 -0.990609
# 102   69.0  0.298503  2.142722 -1.542143  1.561332  0.938108 -2.145673
# 990  748.0  1.094987 -0.162972  0.497779  0.711234 -0.791207 -0.946770
#
#            V7        V8        V9  ...       V21       V22       V23  \
# 99   0.066240 -0.196940  0.075921  ... -0.251566 -0.770139  0.125998
# 102  1.405569 -0.778459  0.328636  ... -0.290987 -0.000235  0.092174
# 990 -0.026046 -0.092115  0.373153  ... -0.279243 -1.081350  0.131340
#
#           V24       V25       V26       V27       V28  Amount  Class
# 99   0.369627  0.205598  0.094062 -0.033138  0.020990   15.99    '0'
# 102  0.586205 -0.397314 -0.480949  0.251145 -0.242279    0.78    '0'
# 990  0.325433  0.047068  0.030939 -0.050226  0.032226   82.39    '0'
#
# [3 rows x 31 columns]

# %%
print(len(cc.drop_duplicates()))
print(len(cc[cc.duplicated()]))
# Out:
# 283726
# 1081

# %%
cc.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
cc['Time'].describe()
# Out:
# count    284807.000000
# mean      94813.859575
# std       47488.145955
# min           0.000000
# 25%       54201.500000
# 50%       84692.000000
# 75%      139320.500000
# max      172792.000000
# Name: Time, dtype: float64

# %%
cc['Class'].value_counts(normalize = True)
# Out:
# '0'    0.998273
# '1'    0.001727
# Name: Class, dtype: float64

# %%
cc.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17
# V2     -0.010593  4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16
# V3     -0.419618 -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16
# V4     -0.105260  1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00
# V5      0.173072  6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15
# V6     -0.063016  2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16
# V7      0.084714  1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16
# V8     -0.036949 -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16
# V9     -0.008660  2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16
# V10     0.030617  7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16
# V11    -0.247689  2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16
# ...

# %%
cc.shape
# Out:
# (284807, 31)

# %%
cc.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
cc[['V1','V4']].head(20)
# Out:
#           V1        V4
# 0  -1.359807  1.378155
# 1   1.191857  0.448154
# 2  -1.358354  0.379780
# 3  -0.966272 -0.863291
# 4  -1.158233  0.403034
# 5  -0.425966 -0.168252
# 6   1.229658  1.202613
# 7  -0.644269 -0.492199
# 8  -0.894286 -0.271526
# 9  -0.338262 -0.222187
# 10  1.449044 -1.375667
# 11  0.384978 -0.094019
# 12  1.249999 -1.234899
# 13  1.069374  2.712520
# 14 -2.791855  1.767473
# 15 -0.752417 -1.468643
# 16  1.103215  1.289091
# 17 -0.436905 -0.727219
# 18 -5.401258  1.736239
# 19  1.492936 -1.438026

# %%
cc.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 284802    False
# 284803    False
# 284804    False
# 284805    False
# 284806    False
# Length: 284807, dtype: bool

# %%
import matplotlib.pyplot as mlp
# %matplotlib inline
plt.boxplot(cc['Amount'])
plt.show()

# %%
import matplotlib.pyplot as mlp
# %matplotlib inline
cc.hist(column='Time',figsize=[20,10])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002411199DC40>]],
#       dtype=object)

# %%
cc.hist(column='Amount',figsize=[20,10])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002E90E623A90>]],
#       dtype=object)

# %%
cc.boxplot(column='Time',figsize=(15,10))

# %%
import matplotlib.pyplot as mlp
# %matplotlib inline
cc["Time"].value_counts().head(10).plot(kind="bar")

# %%
cc["Amount"].value_counts().head(10).plot(kind="line")

# %%
cc['Time'].value_counts().head(10).plot(kind="pie")
